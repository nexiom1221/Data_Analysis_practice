# %%
import tweepy

CONSUMER_KEY = "{your key}"
CONSUMER_SECRET = "{your key}"
ACCESS_TOKEN_KEY = "{your key}"
ACCESS_TOKEN_SECRET = "{your key}"

auth = tweepy.OAuthHandler(CONSUMER_KEY, CONSUMER_SECRET)

auth.set_access_token(ACCESS_TOKEN_KEY, ACCESS_TOKEN_SECRET)

api = tweepy.API(auth)

keyword = "손흥민"
tweets = api.search(keyword)
for tweet in tweets:
    print(tweet.entities['user_mentions'])
    print(tweet.entities['hashtags'])
    print(tweet.text)
# Out:
# [{'screen_name': 'YouTube', 'name': 'YouTube', 'id': 10228272, 'id_str': '10228272', 'indices': [64, 72]}]
# []
# [일본반응] 손흥민의 70m 독주골, 프리미어리그 올해의 골 선정 https://t.co/bUzhN34asp 출처 @YouTube
# [{'screen_name': 'kelawares', 'name': 'Kel', 'id': 331505553, 'id_str': '331505553', 'indices': [0, 10]}]
# []
# @kelawares 아뇨, 전 야알못이에요. 갖고 싶은 건 손흥민 사인 축구공이에요.
# [{'screen_name': 'sooilli', 'name': '쏘쏘', 'id': 1044447686164795393, 'id_str': '1044447686164795393', 'indices': [3, 11]}]
# []
# RT @sooilli: 손흥민 출국 조심히가 ㅠㅠ
# 착장 완전 귀엽네 소능민.. https://t.co/DqI40feSU5
# []
# []
# 손 손흥민 흥 흥해라 민 민망하다
# [{'screen_name': 'DeesinenySmile', 'name': '🇰🇷🇹🇭Sonheungmin FCThai🐇🐓', 'id': 2436642744, 'id_str': '2436642744', 'indices': [3, 18]}]
# [{'text': 'HMFCT07', 'indices': [84, 92]}, {'text': 'SON7', 'indices': [93, 98]}, {'text': 'COYS', 'indices': [99, 104]}, {'text': 'THFC', 'indices': [105, 110]}, {'text': 'Sonny', 'indices': [111, 117]}, {'text': 'SON7', 'indices': [118, 123]}, {'text': '손흥민', 'indices': [124, 128]}]
# RT @DeesinenySmile: ยินดีต้อนรับโจ ฮาร์ท สู่ท็อตแน่มนะฮะ 👍👍👍
#
# เซ็นสัญญาถึงปี 2022
#
# #HMFCT07 #SON7 #COYS #THFC​#Sonny​#SON7​#손흥민​ #sonheung…
# []
# [{'text': 'HMFCT07', 'indices': [64, 72]}, {'text': 'SON7', 'indices': [73, 78]}, {'text': 'COYS', 'indices': [79, 84]}, {'text': 'THFC', 'indices': [85, 90]}, {'text': 'Sonny', 'indices': [91, 97]}, {'text': 'SON7', 'indices': [98, 103]}, {'text': '손흥민', 'indices': [104, 108]}]
# ยินดีต้อนรับโจ ฮาร์ท สู่ท็อตแน่มนะฮะ 👍👍👍
#
# เซ็นสัญญาถึงปี 2022
#
# #HMFCT07 #SON7 #COYS #THFC​#Sonny​#SON7​#손흥민​… https://t.co/VeQt9ILOZM
# []
# [{'text': 'HMSJ07', 'indices': [27, 34]}, {'text': 'HMFCT07', 'indices': [35, 43]}, {'text': 'SON7', 'indices': [44, 49]}, {'text': '손흥민', 'indices': [50, 54]}, {'text': 'Sonny', 'indices': [55, 61]}, {'text': 'COYS', 'indices': [62, 67]}, {'text': 'THFC', 'indices': [68, 73]}, {'text': 'sonheungminFCThai', 'indices': [74, 92]}]
# อปป้าช่วยกันขายของสินะ​👍👍👍
# #HMSJ07​#HMFCT07​#SON7​#손흥민​#Sonny​#COYS​#THFC​#sonheungminFCThai https://t.co/CUY8rw02cQ
# [{'screen_name': 'sooilli', 'name': '쏘쏘', 'id': 1044447686164795393, 'id_str': '1044447686164795393', 'indices': [3, 11]}]
# []
# RT @sooilli: 손흥민 출국 조심히가 ㅠㅠ
# 착장 완전 귀엽네 소능민.. https://t.co/DqI40feSU5
# []
# [{'text': 'TottenhamHotspur', 'indices': [0, 17]}, {'text': 'Tottenham', 'indices': [18, 28]}, {'text': 'Spurs', 'indices': [29, 35]}, {'text': '토트넘', 'indices': [36, 40]}, {'text': '손흥민', 'indices': [41, 45]}, {'text': 'Deli', 'indices': [46, 51]}, {'text': 'DeliAlli', 'indices': [52, 61]}, {'text': 'HugoLloris', 'indices': [62, 73]}]
# #TottenhamHotspur #Tottenham #Spurs #토트넘 #손흥민 #Deli #DeliAlli #HugoLloris https://t.co/ZnOfwLSFmI
# []
# []
# [Airport Fashion]
# Who: Son Heung-Min
# When: 2020년 8월 17일
# Where: Airport Fashion
# What: CARTIER Pasha De Cartier Watch… https://t.co/IkGOyvbcvi
# [{'screen_name': 'sooilli', 'name': '쏘쏘', 'id': 1044447686164795393, 'id_str': '1044447686164795393', 'indices': [3, 11]}]
# []
# RT @sooilli: 손흥민 출국 조심히가 ㅠㅠ
# 착장 완전 귀엽네 소능민.. https://t.co/DqI40feSU5
# [{'screen_name': 'sooilli', 'name': '쏘쏘', 'id': 1044447686164795393, 'id_str': '1044447686164795393', 'indices': [3, 11]}]
# []
# RT @sooilli: 손흥민 출국 조심히가 ㅠㅠ
# 착장 완전 귀엽네 소능민.. https://t.co/DqI40feSU5
# [{'screen_name': 'cutest_HM_', 'name': '손흥민세상에서제일귀여워', 'id': 1040174376090386435, 'id_str': '1040174376090386435', 'indices': [3, 14]}]
# [{'text': '손흥민', 'indices': [65, 69]}, {'text': '이승우', 'indices': [70, 74]}]
# RT @cutest_HM_: 190611 A매치 이란전
#
# 고생했어 👏
#
# https://t.co/R7INfg1GEN
#
# #손흥민 #이승우 https://t.co/Djq98GsXfb
# []
# []
# 맨시티 감독이 살아 남는다면
# 손흥민 생각이 간절할것 같다
# 손흥민 있었으면 수월하게 이겼을텐데
# 나는 손흥민이 맨시티 갔으면 좋겠다
# 지금도 우승권이니 손흥민 가면 손흥민도 챔피언싑컵 쟁취하는 포인트를 찍을텐데
# 손흥민 맨시티 가서 일석삼조 얻어라
# []
# []
# 라면 하나하나에 다
# 손흥민이 있어서 부담스러워.. https://t.co/KAJpDXX4Kf

# %%
# %matplotlib inline

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import tweepy

CONSUMER_KEY = "{your key}"
CONSUMER_SECRET = "{your key}"
ACCESS_TOKEN_KEY = "{your key}"
ACCESS_TOKEN_SECRET = "{your key}"

auth = tweepy.OAuthHandler(CONSUMER_KEY, CONSUMER_SECRET)

auth.set_access_token(ACCESS_TOKEN_KEY, ACCESS_TOKEN_SECRET)

api = tweepy.API(auth)

keyword = "손흥민"
columns = ['created', 'tweet_text']
df = pd.DataFrame(columns=columns)

for i in range(1,100):
    print("Get data", str(i/500*100), "% complete..")
    tweets = api.search(keyword)
    for tweet in tweets:
        tweet_text = tweet.text
        created = tweet.created_at
        row = [created, tweet_text]
        series = pd.Series(row, index=df.columns)
        df = df.append(series, ignore_index = True)

    
print("Get data 100 % complete..")
df.head()
# Out:
# Get data 0.2 % complete..
# Get data 0.4 % complete..
# Get data 0.6 % complete..
# Get data 0.8 % complete..
# Get data 1.0 % complete..
# Get data 1.2 % complete..
# Get data 1.4000000000000001 % complete..
# Get data 1.6 % complete..
# Get data 1.7999999999999998 % complete..
# Get data 2.0 % complete..
# Get data 2.1999999999999997 % complete..
# Get data 2.4 % complete..
# Get data 2.6 % complete..
# Get data 2.8000000000000003 % complete..
# Get data 3.0 % complete..
# Get data 3.2 % complete..
# Get data 3.4000000000000004 % complete..
# Get data 3.5999999999999996 % complete..
# Get data 3.8 % complete..
# Get data 4.0 % complete..
# Get data 4.2 % complete..
# Get data 4.3999999999999995 % complete..
# Get data 4.6 % complete..
# Get data 4.8 % complete..
# Get data 5.0 % complete..
# Get data 5.2 % complete..
# Get data 5.4 % complete..
# Get data 5.6000000000000005 % complete..
# Get data 5.800000000000001 % complete..
# Get data 6.0 % complete..
# Get data 6.2 % complete..
# Get data 6.4 % complete..
# Get data 6.6000000000000005 % complete..
# Get data 6.800000000000001 % complete..
# Get data 7.000000000000001 % complete..
# Get data 7.199999999999999 % complete..
# Get data 7.3999999999999995 % complete..
# Get data 7.6 % complete..
# Get data 7.8 % complete..
# Get data 8.0 % complete..
# Get data 8.200000000000001 % complete..
# Get data 8.4 % complete..
# Get data 8.6 % complete..
# Get data 8.799999999999999 % complete..
# Get data 9.0 % complete..
# Get data 9.2 % complete..
# Get data 9.4 % complete..
# Get data 9.6 % complete..
# Get data 9.8 % complete..
# Get data 10.0 % complete..
# Get data 10.2 % complete..
# Get data 10.4 % complete..
# Get data 10.6 % complete..
# Get data 10.8 % complete..
# Get data 11.0 % complete..
# Get data 11.200000000000001 % complete..
# Get data 11.4 % complete..
# Get data 11.600000000000001 % complete..
# Get data 11.799999999999999 % complete..
# Get data 12.0 % complete..
# Get data 12.2 % complete..
# Get data 12.4 % complete..
# Get data 12.6 % complete..
# Get data 12.8 % complete..
# Get data 13.0 % complete..
# Get data 13.200000000000001 % complete..
# Get data 13.4 % complete..
# Get data 13.600000000000001 % complete..
# Get data 13.8 % complete..
# Get data 14.000000000000002 % complete..
# Get data 14.2 % complete..
# Get data 14.399999999999999 % complete..
# Get data 14.6 % complete..
# Get data 14.799999999999999 % complete..
# Get data 15.0 % complete..
# Get data 15.2 % complete..
# Get data 15.4 % complete..
# Get data 15.6 % complete..
# Get data 15.8 % complete..
# Get data 16.0 % complete..
# Get data 16.2 % complete..
# Get data 16.400000000000002 % complete..
# Get data 16.6 % complete..
# Get data 16.8 % complete..
# Get data 17.0 % complete..
# Get data 17.2 % complete..
# Get data 17.4 % complete..
# Get data 17.599999999999998 % complete..
# Get data 17.8 % complete..
# Get data 18.0 % complete..
# Get data 18.2 % complete..
# Get data 18.4 % complete..
# Get data 18.6 % complete..
# Get data 18.8 % complete..
# Get data 19.0 % complete..
# Get data 19.2 % complete..
# Get data 19.400000000000002 % complete..
# Get data 19.6 % complete..
# Get data 19.8 % complete..
# Get data 100 % complete..
#               created                                         tweet_text
# 0 2020-09-01 01:17:22  RT @sooilli: The New Volvo S90 손흥민 광고\n볼보 사이트 ...
# 1 2020-09-01 01:11:48  아시발얘아직도이래ㅋㅋㅋㅋㅋ... 가수가 국가에 뭔 역할을 하냐고 지랄 국위선양은 손...
# 2 2020-09-01 00:42:38  RT @sooilli: The New Volvo S90 손흥민 광고\n볼보 사이트 ...
# 3 2020-09-01 00:31:10  RT @sooilli: The New Volvo S90 손흥민 광고\n볼보 사이트 ...
# 4 2020-08-31 23:42:40  [#EVENT] 새로운 하나원큐 손흥민 CF 메이킹필름\n최초공개 이모티콘 이벤트\...

# %%
import re

def text_cleaning(text):
    hangul = re.compile('[^ ㄱ-ㅣ가-힣]+')
    result = hangul.sub('',text)
    return result

df['ko_text'] = df['tweet_text'].apply(lambda x: text_cleaning(x))
df.head()
# Out:
#               created                                         tweet_text  \
# 0 2020-09-01 01:17:22  RT @sooilli: The New Volvo S90 손흥민 광고\n볼보 사이트 ...
# 1 2020-09-01 01:11:48  아시발얘아직도이래ㅋㅋㅋㅋㅋ... 가수가 국가에 뭔 역할을 하냐고 지랄 국위선양은 손...
# 2 2020-09-01 00:42:38  RT @sooilli: The New Volvo S90 손흥민 광고\n볼보 사이트 ...
# 3 2020-09-01 00:31:10  RT @sooilli: The New Volvo S90 손흥민 광고\n볼보 사이트 ...
# 4 2020-08-31 23:42:40  [#EVENT] 새로운 하나원큐 손흥민 CF 메이킹필름\n최초공개 이모티콘 이벤트\...
#
#                                              ko_text
# 0                      손흥민 광고볼보 사이트 메인에 뜬 흥민 광고 ㅠㅠ
# 1  아시발얘아직도이래ㅋㅋㅋㅋㅋ 가수가 국가에 뭔 역할을 하냐고 지랄 국위선양은 손흥민이...
# 2                      손흥민 광고볼보 사이트 메인에 뜬 흥민 광고 ㅠㅠ
# 3                      손흥민 광고볼보 사이트 메인에 뜬 흥민 광고 ㅠㅠ
# 4       새로운 하나원큐 손흥민  메이킹필름최초공개 이모티콘 이벤트 이벤트 참여하기

# %%
from konlpy.tag import Okt
from collections import Counter

korean_stopwords_path = "../data/korean_stopwords.txt"
with open(korean_stopwords_path, encoding='utf8') as f:
    stopwords = f.readlines()
stopwords = [x.strip() for x in stopwords]

def get_nouns(x):
    nouns_tagger = Okt()
    nouns = nouns_tagger.nouns(x)
    
    nouns = [noun for noun in nouns if len(noun) > 1]
    
    nouns = [noun for noun in nouns if noun not in stopwords]
    
    return nouns

df['nouns'] = df['ko_text'].apply(lambda x: get_nouns(x))
print(df.shape)
df.head()
# Out:
# (1485, 4)
#               created                                         tweet_text  \
# 0 2020-09-01 01:17:22  RT @sooilli: The New Volvo S90 손흥민 광고\n볼보 사이트 ...
# 1 2020-09-01 01:11:48  아시발얘아직도이래ㅋㅋㅋㅋㅋ... 가수가 국가에 뭔 역할을 하냐고 지랄 국위선양은 손...
# 2 2020-09-01 00:42:38  RT @sooilli: The New Volvo S90 손흥민 광고\n볼보 사이트 ...
# 3 2020-09-01 00:31:10  RT @sooilli: The New Volvo S90 손흥민 광고\n볼보 사이트 ...
# 4 2020-08-31 23:42:40  [#EVENT] 새로운 하나원큐 손흥민 CF 메이킹필름\n최초공개 이모티콘 이벤트\...
#
#                                              ko_text  \
# 0                      손흥민 광고볼보 사이트 메인에 뜬 흥민 광고 ㅠㅠ
# 1  아시발얘아직도이래ㅋㅋㅋㅋㅋ 가수가 국가에 뭔 역할을 하냐고 지랄 국위선양은 손흥민이...
# 2                      손흥민 광고볼보 사이트 메인에 뜬 흥민 광고 ㅠㅠ
# 3                      손흥민 광고볼보 사이트 메인에 뜬 흥민 광고 ㅠㅠ
# 4       새로운 하나원큐 손흥민  메이킹필름최초공개 이모티콘 이벤트 이벤트 참여하기
#
#                                                nouns
# 0                     [손흥민, 광고, 볼보, 사이트, 메인, 흥민, 광고]
# 1  [아시, 발얘, 직도, 가수, 국가, 역할, 지랄, 국위, 선양, 손흥민, 페이커,...
# 2                     [손흥민, 광고, 볼보, 사이트, 메인, 흥민, 광고]
# 3                     [손흥민, 광고, 볼보, 사이트, 메인, 흥민, 광고]
# 4    [하나원, 손흥민, 메이킹, 필름, 최초, 공개, 이모티콘, 이벤트, 이벤트, 참여]

# %%
from apyori import apriori

transactions = [
    ['손흥민', '시소코'],
    ['손흥민', '케인'],
    ['손흥민', '케인', '포체티노']
]

results = list(apriori(transactions))

for result in results:
    print(result)
# Out:
# RelationRecord(items=frozenset({'손흥민'}), support=1.0, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'손흥민'}), confidence=1.0, lift=1.0)])
# RelationRecord(items=frozenset({'시소코'}), support=0.3333333333333333, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'시소코'}), confidence=0.3333333333333333, lift=1.0)])
# RelationRecord(items=frozenset({'케인'}), support=0.6666666666666666, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'케인'}), confidence=0.6666666666666666, lift=1.0)])
# RelationRecord(items=frozenset({'포체티노'}), support=0.3333333333333333, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'포체티노'}), confidence=0.3333333333333333, lift=1.0)])
# RelationRecord(items=frozenset({'시소코', '손흥민'}), support=0.3333333333333333, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'시소코', '손흥민'}), confidence=0.3333333333333333, lift=1.0), OrderedStatistic(items_base=frozenset({'손흥민'}), items_add=frozenset({'시소코'}), confidence=0.3333333333333333, lift=1.0), OrderedStatistic(items_base=frozenset({'시소코'}), items_add=frozenset({'손흥민'}), confidence=1.0, lift=1.0)])
# RelationRecord(items=frozenset({'케인', '손흥민'}), support=0.6666666666666666, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'케인', '손흥민'}), confidence=0.6666666666666666, lift=1.0), OrderedStatistic(items_base=frozenset({'손흥민'}), items_add=frozenset({'케인'}), confidence=0.6666666666666666, lift=1.0), OrderedStatistic(items_base=frozenset({'케인'}), items_add=frozenset({'손흥민'}), confidence=1.0, lift=1.0)])
# RelationRecord(items=frozenset({'포체티노', '손흥민'}), support=0.3333333333333333, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'포체티노', '손흥민'}), confidence=0.3333333333333333, lift=1.0), OrderedStatistic(items_base=frozenset({'손흥민'}), items_add=frozenset({'포체티노'}), confidence=0.3333333333333333, lift=1.0), OrderedStatistic(items_base=frozenset({'포체티노'}), items_add=frozenset({'손흥민'}), confidence=1.0, lift=1.0)])
# RelationRecord(items=frozenset({'포체티노', '케인'}), support=0.3333333333333333, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'포체티노', '케인'}), confidence=0.3333333333333333, lift=1.0), OrderedStatistic(items_base=frozenset({'케인'}), items_add=frozenset({'포체티노'}), confidence=0.5, lift=1.5), OrderedStatistic(items_base=frozenset({'포체티노'}), items_add=frozenset({'케인'}), confidence=1.0, lift=1.5)])
# RelationRecord(items=frozenset({'포체티노', '케인', '손흥민'}), support=0.3333333333333333, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'포체티노', '케인', '손흥민'}), confidence=0.3333333333333333, lift=1.0), OrderedStatistic(items_base=frozenset({'손흥민'}), items_add=frozenset({'포체티노', '케인'}), confidence=0.3333333333333333, lift=1.0), OrderedStatistic(items_base=frozenset({'케인'}), items_add=frozenset({'포체티노', '손흥민'}), confidence=0.5, lift=1.5), OrderedStatistic(items_base=frozenset({'포체티노'}), items_add=frozenset({'케인', '손흥민'}), confidence=1.0, lift=1.5), OrderedStatistic(items_base=frozenset({'케인', '손흥민'}), items_add=frozenset({'포체티노'}), confidence=0.5, lift=1.5), OrderedStatistic(items_base=frozenset({'포체티노', '손흥민'}), items_add=frozenset({'케인'}), confidence=1.0, lift=1.5), OrderedStatistic(items_base=frozenset({'포체티노', '케인'}), items_add=frozenset({'손흥민'}), confidence=1.0, lift=1.0)])

# %%
transactions = df['nouns'].tolist()

transactions = [transaction for transaction in transactions if transaction]
print(transactions)
# Out:
# [['손흥민', '광고', '볼보', '사이트', '메인', '흥민', '광고'], ['아시', '발얘', '직도', '가수', '국가', '역할', '지랄', '국위', '선양', '손흥민', '페이커', '정도', '여야', '삼성', '직원', '면제', '하라', '시발', '계속', '시비'], ['손흥민', '광고', '볼보', '사이트', '메인', '흥민', '광고'], ['손흥민', '광고', '볼보', '사이트', '메인', '흥민', '광고'], ['하나원', '손흥민', '메이킹', '필름', '최초', '공개', '이모티콘', '이벤트', '이벤트', '참여'], ['손흥민', '광고', '볼보', '사이트', '메인', '흥민', '광고'], ['손흥민', '진짴', '화해', '분다', '댕댕'], ['손흥민'], ['손흥민'], ['손흥민', '광고', '볼보', '사이트', '메인', '흥민', '광고'], ['손흥민', '감탄', '창덕', '체험'], ['손흥민', '광고', '볼보', '사이트', '메인', '흥민', '광고'], ['손흥민', '광고', '볼보', '사이트', '메인', '흥민', '광고'], ['손흥민'], ['손흥민', '광고', '볼보', '사이트', '메인', '흥민', '광고'], ['아시', '발얘', '직도', '가수', '국가', '역할', '지랄', '국위', '선양', '손흥민', '페이커', '정도', '여야', '삼성', '직원', '면제', '하라', '시발', '계속', '시비'], ['손흥민', '광고', '볼보', '사이트', '메인', '흥민', '광고'], ['손흥민', '광고', '볼보', '사이트', '메인', '흥민', '광고'], ['하나원', '손흥민', '메이킹', '필름', '최초', '공개', '이모티콘', '이벤트', '이벤트', '참여'], ['손흥민', '광고', '볼보', '사이트', '메인', '흥민', '광고'], ['손흥민', '진짴', '화해', '분다', '댕댕'], ['손흥민'], ['손흥민'], ['손흥민', '광고', '볼보', '사이트', '메인', '흥민', '광고'], ['손흥민', '감탄', '창덕', '체험'], ['손흥민', '광고', '볼보', '사이트', '메인', '흥민', '광고'], ['손흥민', '광고', '볼보', '사이트', '메인', '흥민', '광고'], ['손흥민'], ['손흥민', '광고', '볼보', '사이트', '메인', '흥민', '광고'], ['아시', '발얘', '직도', '가수', '국가', '역할', '지랄', '국위', '선양', '손흥민', '페이커', '정도', '여야', '삼성', '직원', '면제', '하라', '시발', '계속', '시비'], ['손흥민', '광고', '볼보', '사이트', '메인', '흥민', '광고'], ['손흥민', '광고', '볼보', '사이트', '메인', '흥민', '광고'], ['하나원', '손흥민', '메이킹', '필름', '최초', '공개', '이모티콘', '이벤트', '이벤트', '참여'], ['손흥민', '광고', '볼보', '사이트', '메인', '흥민', '광고'], ['손흥민', '진짴', '화해', '분다', '댕댕'], ['손흥민'], ['손흥민'], ['손흥민', '광고', '볼보', '사이트', '메인', '흥민', '광고'], ['손흥민', '감탄', '창덕', '체험'], ['손흥민', '광고', '볼보', '사이트', '메인', '흥민', '광고'], ['손흥민', '광고', '볼보', '사이트', '메인', '흥민', '광고'], ['손흥민'], ['손흥민', '광고', '볼보', '사이트', '메인', '흥민', '광고'], ['아시', '발얘', '직도', '가수', '국가', '역할', '지랄', '국위', '선양', '손흥민', '페이커', '정도', '여야', '삼성', '직원', '면제', '하라', '시발', '계속', '시비'], ['손흥민', '광고', '볼보', '사이트', '메인', '흥민', '광고'], ['손흥민', '광고', '볼보', '사이트', '메인', '흥민', '광고'], ['하나원', '손흥민', '메이킹', '필름', '최초', '공개', '이모티콘', '이벤트', '이벤트', '참여'], ['손흥민', '광고', '볼보', '사이트', '메인', '흥민', '광고'], ['손흥민', '진짴', '화해', '분다', '댕댕'], ['손흥민'], ['손흥민'], ['손흥민', '광고', '볼보', '사이트', '메인', '흥민', '광고'], ['손흥민', '감탄', '창덕', '체험'], ['손흥민', '광고', '볼보', '사이트', '메인', '흥민', '광고'], ['손흥민', '광고', '볼보', '사이트', '메인', '흥민', '광고'], ['손흥민'], ['손흥민', '광고', '볼보', '사이트', '메인', '흥민', '광고'], ['아시', '발얘', '직도', '가수', '국가', '역할', '지랄', '국위', '선양', '손흥민', '페이커', '정도', '여야', '삼성', '직원', '면제', '하라', '시발', '계속', '시비'], ['손흥민', '광고', '볼보', '사이트', '메인', '흥민', '광고'], ['손흥민', '광고', '볼보', '사이트', '메인', '흥민', '광고'], ['하나원', '손흥민', '메이킹', '필름', '최초', '공개', '이모티콘', '이벤트', '이벤트', '참여'], ['손흥민', '광고', '볼보', '사이트', '메인', '흥민', '광고'], ['손흥민', '진짴', '화해', '분다', '댕댕'], ['손흥민'], ['손흥민'], ['손흥민', '광고', '볼보', '사이트', '메인', '흥민', '광고'], ['손흥민', '감탄', '창덕', '체험'], ['손흥민', '광고', '볼보', '사이트', '메인', '흥민', '광고'], ['손흥민', '광고', '볼보', '사이트', '메인', '흥민', '광고'], ['손흥민'], ['손흥민', '광고', '볼보', '사이트', '메인', '흥민', '광고'], ['아시', '발얘', '직도', '가수', '국가', '역할', '지랄', '국위', '선양', '손흥민', '페이커', '정도', '여야', '삼성', '직원', '면제', '하라', '시발', '계속', '시비'], ['손흥민', '광고', '볼보', '사이트', '메인', '흥민', '광고'], ['손흥민', '광고', '볼보', '사이트', '메인', '흥민', '광고'], ['하나원', '손흥민', '메이킹', '필름', '최초', '공개', '이모티콘', '이벤트', '이벤트', '참여'], ['손흥민', '광고', '볼보', '사이트', '메인', '흥민', '광고'], ['손흥민', '진짴', '화해', '분다', '댕댕'], ['손흥민'], ['손흥민'], ['손흥민', '광고', '볼보', '사이트', '메인', '흥민', '광고'], ['손흥민', '감탄', '창덕', '체험'], ['손흥민', '광고', '볼보', '사이트', '메인', '흥민', '광고'], ['손흥민', '광고', '볼보', '사이트', '메인', '흥민', '광고'], ['손흥민'], ['손흥민', '광고', '볼보', '사이트', '메인', '흥민', '광고'], ['아시', '발얘', '직도', '가수', '국가', '역할', '지랄', '국위', '선양', '손흥민', '페이커', '정도', '여야', '삼성', '직원', '면제', '하라', '시발', '계속', '시비'], ['손흥민', '광고', '볼보', '사이트', '메인', '흥민', '광고'], ['손흥민', '광고', '볼보', '사이트', '메인', '흥민', '광고'], ['하나원', '손흥민', '메이킹', '필름', '최초', '공개', '이모티콘', '이벤트', '이벤트', '참여'], ['손흥민', '광고', '볼보', '사이트', '메인', '흥민', '광고'], ['손흥민', '진 ...

# %%
results = list(apriori(transactions, min_support=0.1, min_confidence=0.2, min_lift=1, max_length=2))
print(results)
# Out:
# [RelationRecord(items=frozenset({'광고'}), support=0.5, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'광고'}), confidence=0.5, lift=1.0)]), RelationRecord(items=frozenset({'메인'}), support=0.5, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'메인'}), confidence=0.5, lift=1.0)]), RelationRecord(items=frozenset({'볼보'}), support=0.5, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'볼보'}), confidence=0.5, lift=1.0)]), RelationRecord(items=frozenset({'사이트'}), support=0.5, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'사이트'}), confidence=0.5, lift=1.0)]), RelationRecord(items=frozenset({'손흥민'}), support=1.0, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'손흥민'}), confidence=1.0, lift=1.0)]), RelationRecord(items=frozenset({'흥민'}), support=0.5, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'흥민'}), confidence=0.5, lift=1.0)]), RelationRecord(items=frozenset({'광고', '메인'}), support=0.5, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'광고', '메인'}), confidence=0.5, lift=1.0), OrderedStatistic(items_base=frozenset({'광고'}), items_add=frozenset({'메인'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'메인'}), items_add=frozenset({'광고'}), confidence=1.0, lift=2.0)]), RelationRecord(items=frozenset({'볼보', '광고'}), support=0.5, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'볼보', '광고'}), confidence=0.5, lift=1.0), OrderedStatistic(items_base=frozenset({'광고'}), items_add=frozenset({'볼보'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'볼보'}), items_add=frozenset({'광고'}), confidence=1.0, lift=2.0)]), RelationRecord(items=frozenset({'광고', '사이트'}), support=0.5, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'광고', '사이트'}), confidence=0.5, lift=1.0), OrderedStatistic(items_base=frozenset({'광고'}), items_add=frozenset({'사이트'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'사이트'}), items_add=frozenset({'광고'}), confidence=1.0, lift=2.0)]), RelationRecord(items=frozenset({'광고', '손흥민'}), support=0.5, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'광고', '손흥민'}), confidence=0.5, lift=1.0), OrderedStatistic(items_base=frozenset({'광고'}), items_add=frozenset({'손흥민'}), confidence=1.0, lift=1.0), OrderedStatistic(items_base=frozenset({'손흥민'}), items_add=frozenset({'광고'}), confidence=0.5, lift=1.0)]), RelationRecord(items=frozenset({'흥민', '광고'}), support=0.5, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'흥민', '광고'}), confidence=0.5, lift=1.0), OrderedStatistic(items_base=frozenset({'광고'}), items_add=frozenset({'흥민'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'흥민'}), items_add=frozenset({'광고'}), confidence=1.0, lift=2.0)]), RelationRecord(items=frozenset({'볼보', '메인'}), support=0.5, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'볼보', '메인'}), confidence=0.5, lift=1.0), OrderedStatistic(items_base=frozenset({'메인'}), items_add=frozenset({'볼보'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'볼보'}), items_add=frozenset({'메인'}), confidence=1.0, lift=2.0)]), RelationRecord(items=frozenset({'메인', '사이트'}), support=0.5, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'메인', '사이트'}), confidence=0.5, lift=1.0), OrderedStatistic(items_base=frozenset({'메인'}), items_add=frozenset({'사이트'}), confidence=1.0, lift=2.0), OrderedStatistic(items_base=frozenset({'사이트'}), items_add=frozenset({'메인'}), confidence=1.0, lift=2.0)]), RelationRecord(items=frozenset({'메인', '손흥민'}), support=0.5, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'메인', '손흥민'}), confidence=0.5, lift=1.0), OrderedStatistic(items_base=frozenset ...

# %%
columns = ['source', 'target', 'support']
network_df = pd.DataFrame(columns=columns)

for result in results:
    if len(result.items) == 2:
        items = [x for x in result.items]
        row = [items[0], items[1], result.support]
        series = pd.Series(row, index=network_df.columns)
        network_df = network_df.append(series, ignore_index=True)
        
network_df.head()
# Out:
#   source target  support
# 0     광고     메인      0.5
# 1     볼보     광고      0.5
# 2     광고    사이트      0.5
# 3     광고    손흥민      0.5
# 4     흥민     광고      0.5

# %%
tweet_corpus = "".join(df['ko_text'].tolist())

from konlpy.tag import Okt
from collections import Counter

nouns_tagger = Okt()
nouns = nouns_tagger.nouns(tweet_corpus)
count = Counter(nouns)

remove_char_counter = Counter({x: count[x] for x in count if len(x) > 1})

node_df = pd.DataFrame(remove_char_counter.items(), columns=['node', 'nodesize'])

node_df = node_df[node_df['nodesize'] >= 50]
node_df.head()
# Out:
#   node  nodesize
# 0  손흥민      1386
# 1   광고      1386
# 2   볼보       693
# 3  사이트       693
# 4   메인       693

# %%
import networkx as nx
plt.figure(figsize=(25,25))

G = nx.Graph()

for index, row in node_df.iterrows():
    G.add_node(row['node'], nodesize=row['nodesize'])
    
for index, row in network_df.iterrows():
    G.add_weighted_edges_from([(row['source'], row['target'], row['support'])])
    
pos = nx.spring_layout(G, k=0.6, iterations=50)
sizes = [G.nodes[node]['nodesize']*25 for node in G]
nx.draw(G, pos=pos, node_size=sizes)

nx.draw_networkx_labels(G, pos=pos, font_family='Malgun Gothic', font_size=25)

ax = plt.gca()
plt.show()
